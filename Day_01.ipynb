# %% [markdown]
# ## 1. What is Data Point?
# Data Point means the specific point where each aixs of the data meets together.

# %% [markdown]
# ## 2. What is X-axis, Y-axis?
#
# x-axis = Horizontal line of the graph (-)
# y-axis = Vertical line of the graph (|)

# %% [markdown]
# ## 3. What is a figure?
# A canvas or simply a paper where drawing is performed.

# %% [markdown]
# ## 4. What is Axes?
# Inside a canvas (Paper), we can stack a graph paper and whole graph paper is called Axes

# %% [markdown]
# ## 5. What is Plot?
# A plot is a visual representation of data using shapes like lines, bars, dots, or curves to show patterns, relationships, or trends.

# %% [markdown]
# ## 6. What is a marker?
# A marker is a symbol used to represent individual data points on a plot.
#
# ## Common types of marker:
# 🧩 Common Marker Shapes
# | Symbol | Shape |
#
# | 'o' | Circle |
#
# | 's' | Square |
#
# | '^' | Triangle Up |
#
# | 'x' | X |
#
# | '+' | Plus |
#
# | '*' | Star |
#
# | '.' | Dot |

# %%
# Example of a marker

import matplotlib.pyplot as plt

x = [10, 20, 34]
y = [1, 2, 3]

fig = plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black')  # Creates diamond-shaped markers at each data point (x, y)

# %% [markdown]
# ## 7. What is line?
# A line is a sign showing the connection between each and every data points.
# - There is blue line connecting each data points in above fig.

# %% [markdown]
# ## 8. What is line style?
# In matplotlib, linestyle controls the appearance of the line that connects your data points.
# It defines how the line looks — solid, dashed, dotted, etc.
# 🧪 Common linestyle Options
# | Symbol | Style Name | Description |
#
# | '-' | Solid line | Default continuous line |
#
# | '--' | Dashed line | Line with dashes |
#
# | '-.' | Dash-dot line | Dash followed by a dot |
#
# | ':' | Dotted line | Line made of dots |

# %%
x = [10, 20, 34]
y = [1, 2, 3]

plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = '--')  # Creates diamond-shaped markers at each data point (x, y)


plt.show()

# %%
x = [10, 20, 34]
y = [1, 2, 3]

plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = '-.')  # Creates diamond-shaped markers at each data point (x, y)


plt.show()

# %%
x = [10, 20, 34]
y = [1, 2, 3]

plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = '-')  # Creates diamond-shaped markers at each data point (x, y)


plt.show()

# %%
x = [10, 20, 34]
y = [1, 2, 3]

plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = ':', color='gray')  # Creates diamond-shaped markers at each data point (x, y)


plt.show()

# %% [markdown]
# ## 9. What is legend?
# A legend in matplotlib is a small box that explains what each plotted line, marker, or shape represents.
# It maps labels to visual elements in your plot — like colors, line styles, or markers — so viewers can understand what they’re looking at.

# %%
x = [10, 20, 34]
y = [1, 2, 3]
plt.xlabel('Value of x')
plt.ylabel('Value of y')
plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = ':', color='gray', label='My data series')  # Creates diamond-shaped markers at each data point (x, y)

plt.legend(title="This is a legend", loc='upper center')

plt.show()

# %%
## Grid

# %%
x = [10, 20, 34]
y = [1, 2, 3]
plt.xlabel('Value of x')
plt.ylabel('Value of y')
plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = ':', color='gray', label='My data series')  # Creates diamond-shaped markers at each data point (x, y)

plt.legend(title="This is a legend", loc='upper center')

plt.grid()

plt.show()

# %%
## Title

# %%
x = [10, 20, 34]
y = [1, 2, 3]
plt.xlabel('Value of x')
plt.ylabel('Value of y')
plt.plot(x, y, marker='D', markerfacecolor = 'red', markeredgecolor = 'black', linestyle = ':', color='gray', label='My data series')  # Creates diamond-shaped markers at each data point (x, y)

plt.legend(title="This is a legend", loc='upper center')

plt.title("This is title", fontsize = 20, fontweight = 'bold')
plt.show()

# %% [markdown]
# ## Methods
# A method is a function that is associated with an object.
# It is called using the object it belongs to and often modifies or uses that object’s data.
#
# ## Functions
# A function is a reusable block of code that performs a specific task.
# It is not tied to any object and can be called independently.
